# %%
import pandas as pd
df = pd.read_csv('~/Downloads/20_distinct_colors_revised.csv')

# %%
df
# Out:
#     topic     color      hex              rgb                cmk
# 0       1       Red  #e6194b    (230, 25, 75)    (0, 100, 66, 0)
# 1       2     Green  #3cb44b    (60, 180, 75)    (75, 0, 100, 0)
# 2       3    Yellow  #ffe119   (255, 225, 25)     (0, 25, 95, 0)
# 3       4      Blue  #0082c8    (0, 130, 200)    (100, 35, 0, 0)
# 4       5    Orange  #f58231   (245, 130, 48)     (0, 60, 92, 0)
# 5       6    Purple  #911eb4   (145, 30, 180)     (35, 70, 0, 0)
# 6       7      Cyan  #46f0f0   (70, 240, 240)      (70, 0, 0, 0)
# 7       8   Magenta  #f032e6   (240, 50, 230)     (0, 100, 0, 0)
# 8       9      Lime  #d2f53c   (210, 245, 60)    (35, 0, 100, 0)
# 9      10      Pink  #fabebe  (250, 190, 190)     (0, 30, 15, 0)
# 10     11      Teal  #008080    (0, 128, 128)    (100, 0, 0, 50)
# 11     12  Lavender  #e6beff  (230, 190, 255)     (10, 25, 0, 0)
# 12     13     Brown  #aa6e28   (170, 110, 40)    (0, 35, 75, 33)
# ...

# %%
for i in range(20):
    print(".marker-cluster-"+str(df.topic.values[i]-1)," {\n", "    background-color: rgba"+str(df.rgb.values[i])[:len(df.rgb.values[i])-1]+", 0.5);\n    }")
    print(".marker-cluster-"+str(df.topic.values[i]-1)," div {\n", "    background-color: rgba"+str(df.rgb.values[i])[:len(df.rgb.values[i])-1]+", 0.5);\n    }")
# Out:
# .marker-cluster-0 {
#      background-color: rgba(230, 25, 75, 0.5);
#     }
# .marker-cluster-1 {
#      background-color: rgba(60, 180, 75, 0.5);
#     }
# .marker-cluster-2 {
#      background-color: rgba(255, 225, 25, 0.5);
#     }
# .marker-cluster-3 {
#      background-color: rgba(0, 130, 200, 0.5);
#     }
# .marker-cluster-4 {
#      background-color: rgba(245, 130, 48, 0.5);
#     }
# .marker-cluster-5 {
#      background-color: rgba(145, 30, 180, 0.5);
#     }
# .marker-cluster-6 {
#      background-color: rgba(70, 240, 240, 0.5);
#     }
# .marker-cluster-7 {
#      background-color: rgba(240, 50, 230, 0.5);
#     }
# .marker-cluster-8 {
#      background-color: rgba(210, 245, 60, 0.5);
#     }
# .marker-cluster-9 {
#      background-color: rgba(250, 190, 190, 0.5);
#     }
# .marker-cluster-10 {
#      background-color: rgba(0, 128, 128, 0.5);
#     }
# .marker-cluster-11 {
#      background-color: rgba(230, 190, 255, 0.5);
#     }
# .marker-cluster-12 {
# ...
