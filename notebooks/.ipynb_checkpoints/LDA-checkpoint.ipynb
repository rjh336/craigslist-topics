# %%
import pandas as pd

# %%
df = pd.read_json('../data/posts_preprocessed.json')

# %%
posts = df.prep_body.values.tolist()

# %% [markdown]
# ## Count Vectorizer / TFIDF

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.decomposition import LatentDirichletAllocation

# %%
ngrams = (1,2)

# COUNT VECTORIZER
# vectorizer = CountVectorizer(ngram_range=ngrams)

# TFIDF
vectorizer = TfidfVectorizer(ngram_range=ngrams, max_df=.2)

vectorizer.fit(posts)
x = vectorizer.transform(posts)
x.shape
# Out:
# (19506, 551964)

# %% [markdown]
# ## LDA Model

# %%
# Run LDA
no_topics = 30
lda = LatentDirichletAllocation(n_topics=no_topics).fit(x)
# Out:
# /home/rjh336/anaconda2/envs/metis/lib/python3.5/site-packages/sklearn/decomposition/online_lda.py:294: DeprecationWarning: n_topics has been renamed to n_components in version 0.19 and will be removed in 0.21
#   DeprecationWarning)
# /home/rjh336/anaconda2/envs/metis/lib/python3.5/site-packages/sklearn/decomposition/online_lda.py:532: DeprecationWarning: The default value for 'learning_method' will be changed from 'online' to 'batch' in the release 0.20. This warning was introduced in 0.18.
#   DeprecationWarning)

# %%
def display_topics(model, feature_names, no_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print("Topic %d:" % (topic_idx))
        print("\n".join([feature_names[i] for i in topic.argsort()[:-no_top_words - 1:-1]]))
        print('\n')

# %%
no_top_words = 10
feature_names = vectorizer.get_feature_names()
display_topics(lda, feature_names, no_top_words)
# Out:
# Topic 0:
# christian
# seek work
# metal vocalist
# highway
# paist
# manson
# christian rock
# tim job
# paid posit
# christian band
#
#
# Topic 1:
# de
# la
# en
# para
# que
# lo
# el
# con
# un
# music
#
#
# Topic 2:
# lesson lo
# rock rol
# songbook
# be
# warrior
# weekend warrior
# dirt
# go go
# bluz
# bucket
#
#
# Topic 3:
# aveng
# sevenfold
# aveng sevenfold
# show practic
# punk altern
# lin
# romanc
# ratt
# chemic
# chemic romanc
#
#
# Topic 4:
# book agent
# agent
# interest contact
# follow link
# record video
# rock origin
# henderson academi
# academi music
# prayer
# click link
#
#
# Topic 5:
# michael jackson
# threat
# zip
# ross
# trump
# look blue
# matchbox twenti
# minor threat
# dunn
# rv
#
#
# Topic 6:
# music
# record
# studio
# work
# contact
# lesson
# song
# artist
# show
# guitar
#
#
# Topic 7:
# regga
# tour
# swiss
# fulli fullwood
# fullwood
# hawaii
# bass fulli
# regga artist
# hawaiian
# record
#
#
# Topic 8:
# pittsburgh
# slipknot
# group play
# drummer band
# need place
# jean
# warn
# etc must
# good look
# thank hope
#
#
# Topic 9:
# band
# look
# play
# rock
# music
# player
# like
# drummer
# guitar
# bass
#
#
# Topic 10:
# pm
# god
# sunday
# musician
# thursday
# servic
# friday
# tuesday
# concert
# event
#
#
# Topic 11:
# minneapoli
# crap
# publish
# neededlook
# ro
# pray
# anthem
# loser
# swift
# play church
#
#
# Topic 12:
# viola
# violin viola
# transcript
# intermedi level
# viola cello
# sign label
# chamber
# arpeggio
# brass
# orchestra
#
#
# Topic 13:
# cd
# jesu
# worship
# look femal
# dread
# british
# christ
# mate
# switzerland
# inquiri pleas
#
#
# Topic 14:
# diego
# san diego
# grung
# north counti
# counti san
# band seriou
# sour
# fiddl player
# experi pro
# repli via
#
#
# Topic 15:
# afternoon
# thrash
# rhythm section
# dio
# charli
# look music
# musicians
# style look
# musiciansi
# virtuoso
#
#
# Topic 16:
# event
# parti
# wed
# corpor
# privat
# violin
# special
# corpor event
# duo
# ceremoni
#
#
# Topic 17:
# repair
# guitar
# custom
# piano
# servic
# instrument
# setup
# tune
# design
# fret
#
#
# Topic 18:
# guitarist play
# kimbrough
# like make
# monke
# send contact
# acoust music
# sullivan
# metal singer
# thoma
# tribut act
#
#
# Topic 19:
# desert
# songlist
# dfw
# imperson
# resort
# must also
# costello
# rancid
# classifi
# misti
#
#
# Topic 20:
# trade
# peopl
# bring
# nurs
# nurs home
# home
# lone
# is
# sick
# merl
#
#
# Topic 21:
# petti
# tom
# tom petti
# bluegrass
# mandolin
# banjo
# fiddl
# billi
# rock met
# stone
#
#
# Topic 22:
# dont
# collab
# god
# lamb
# lamb god
# free park
# perform stage
# label look
# hum
# coyn
#
#
# Topic 23:
# time per
# huge plu
# window
# least month
# gig cover
# na jam
# lane
# riot
# make nois
# our
#
#
# Topic 24:
# voic
# sing
# vocal
# coach
# seattl
# voic lesson
# descript
# breath
# singer
# vocal coach
#
#
# Topic 25:
# studio
# room
# space
# rehears
# amp
# mic
# hour
# sound
# avail
# pa
#
#
# Topic 26:
# like hear
# drum machin
# parti entertain
# subscrib
# hear pleas
# nelson
# saturn
# drum drum
# youtub
# hear
#
#
# Topic 27:
# video
# music video
# studio
# shoot
# photo
# film
# locat
# angel
# lo
# audio
#
#
# Topic 28:
# day
# born day
# orlean
# new orlean
# uk singl
# ticket
# az
# diamond
# crue
# motley
#
#
# Topic 29:
# songwriter
# singer songwriter
# citru
# indian
# south florida
# djemb
# pato
# songwriter guitarist
# start look
# request thank

# %% [markdown]
# ## topic exploration

# %%
import numpy as np

# %%
topics_matrix = lda.transform(x)

# %%
def explorer(tm, topic_num, posts):    
    indices = np.argsort(tm[:,topic_num])
    # get top "posts" most probabilistic posts in this topic
    top_indices = indices[len(indices):len(indices)-posts-1:-1]
    for rank, idx in enumerate(top_indices):
        print("POST RANK: ", rank+1)
        print("POST PROB: ", topics_matrix[idx,topic_num])
        print("URL: ",df.url.iloc[idx])
        print("POST CONTENT: ", '\n', df.body.iloc[idx], '\n')
        print("---------------------------------------", '\n')

# %%
explorer(topics_matrix, 18, 20)
# Out:
# POST RANK:  1
# POST PROB:  0.546969696973
# URL:  https://stlouis.craigslist.org/muc/d/6-month-white-pit-bull/6341518154.html
# POST CONTENT:
#  6 month white pit bullshe's a pit female good with kids  and partly potty trained
#
# ---------------------------------------
#
# POST RANK:  2
# POST PROB:  0.501190476191
# URL:  https://neworleans.craigslist.org/muc/d/alienwolf/6344458545.html
# POST CONTENT:
#  ALIENWOLFnew orleans musician alienwolf  latest recording ghosthorn . your invited to listen and download for free.
#
# explore the frequencies of your mind.
#
#  www.reverbnation.com/alienwolf
#
# ---------------------------------------
#
# POST RANK:  3
# POST PROB:  0.501190476191
# URL:  https://sanantonio.craigslist.org/muc/d/alienwolf/6354806607.html
# POST CONTENT:
#  ALIENWOLFnew orleans musician alienwolf latest recording ghosthorn . your invited to listen and download for free.
#
# explore the frequencies of your mind.
#
# www.reverbnation.com/alienwolf
#
# ---------------------------------------
#
# POST RANK:  4
# POST PROB:  0.468758563084
# URL:  https://nh.craigslist.org/muc/d/how-to-kickstart-your-music/6315017820.html
#
# visit our website to request an invite to plaid dog: http://plaiddogrecording.com
#
# ---------------------------------------
#
# POST RANK:  9
# POST PROB:  0.456060606058
# URL:  https://houston.craigslist.org/muc/d/re-metal-singer-lookin-for/6324021967.html
# POST CONTENT:
#  Re: METAL SINGER, lookin for cool metal band to playthis has to be a joke, right?  just horrific.
#
# ---------------------------------------
#
# POST RANK:  10
# POST PROB:  0.437882527844
# URL:  https://houston.craigslist.org/muc/d/metal-singer-lookin-for-cool/6317818130.html
# POST CONTENT:
#  METAL SINGER, lookin for cool metal band to playmore there on my yt
#
# https://www.youtube.com/watch?v=1srmgpboguq
#
#
# https://www.youtube.com/watch?v=_05tdrnmzsk
#
#
# https://www.youtube.com/watch?v=lwaopqhgjqw
#
#
# https://www.youtube.com/watch?v=ttepz9v_ga8
#
# ---------------------------------------
#
# POST RANK:  11
# POST PROB:  0.410606060598
# URL:  https://houston.craigslist.org/muc/d/free-female-vocals-for-rap-or/6312255351.html
# POST CONTENT:
#  free female vocals for rap or rocklet's have fun and record
# listen to my singing on instagram
# gold333rush
#
# ---------------------------------------
#
# POST RANK:  12
# POST PROB:  0.409770191919
# URL:  https://newyork.craigslist.org/brk/muc/d/promote-check-out-my-hit/6346750513.html
# POST CONTENT:
#  Promote/Check Out My Hit Trendy American Dance Songshello,
# a little about me, i am a fresh mixed race ethnic 28 year old music artist/entertainer with some new fun trendy hip hop & dance songs. i just released a fresh trendy comedic fun american hip hop dance single music video about we americans from a song that created over 20k views on youtube and has alot of potential.
#
# musicians, marketers, representers of any kind from new york or online please help me for branding and/or marketing cause of the potential of this song. a small fee is fine depending on the opportunity.thank you for your time. rg
#
# link with my page: https://youtu.be/hwn0iq6bthc
#
# no scams or spams pls
#
# ---------------------------------------
#
# POST RANK:  13
# POST PROB:  0.405916771328
# URL:  https://orlando.craigslist.org/muc/d/new-artist-in-town-aremanny/6324028464.html
# POST CONTENT:
#  NEW ARTIST IN TOWN: AREMANNYthere's a new artist in town and he goes by aremanny. he's a latin urban artist who performs dance-hall, hip-hop, r&b, reggaeton, latin pop, etc., and he's looking forward to performing live!
#
# born in dominican republic, raised in northeastern usa, aremanny now finds himself in orlando pursuing his dream.
#
# check him out here https://www.youtube.com/channel/uc-aftgn94yah6utpnkw-4va
#
# ---------------------------------------
#
# POST RANK:  14
# POST PROB:  0.405916771328
# URL:  https://orlando.craigslist.org/muc/d/new-artist-in-town-aremanny/6322667859.html
# POST CONTENT:
#  NEW ARTIST IN TOWN: AREMANNYthere's a new artist in town and he goes by aremanny. he's a latin urban artist who performs dance-hall, hip-hop, r&b, reggaeton, latin pop, etc., and he's looking forward to performing live!
#
# born in dominican republic, raised in northeastern usa, aremanny now finds himself in orlando pursuing his dream.
#
# check him out here https://www.youtube.com/channel/uc-aftgn94yah6utpnkw-4va
#
# ---------------------------------------
#
# POST RANK:  15
# POST PROB:  0.401666666664
# URL:  https://stlouis.craigslist.org/muc/d/metal-singer-iso-metal-band/6345969078.html
# POST CONTENT:
#  METAL SINGER ISO metal band for crankin - demo linkshttps://www.youtube.com/watch?v=1srmgpboguq
#
#
# https://www.youtube.com/watch?v=_05tdrnmzsk
#
#
# https://www.youtube.com/watch?v=lwaopqhgjqw
#
#
# https://www.youtube.com/watch?v=ttepz9v_ga8
#
# more on my yt channel
#
# ---------------------------------------
#
# POST RANK:  16
# POST PROB:  0.390740740732
# URL:  https://lasvegas.craigslist.org/muc/d/looking-for-bass-player-named/6346658640.html
# POST CONTENT:
#  Looking for a bass player named Jackjack saddler. anyone know him?
#
# mike
#
# ---------------------------------------
#
# POST RANK:  17
# POST PROB:  0.385952380953
# URL:  https://newyork.craigslist.org/mnh/muc/d/pls-check-out-my-new-hit/6359909660.html
# POST CONTENT:
#  PLS Check out my New Hit Trendy TRUMP AMERICA Dance Songhello,
# a little about me, i am a fresh mixed race ethnic 28 year old music artist/entertainer with some  new fun trendy hip hop & dance songs. i just released a fresh trendy comedic fun american hip hop dance single music video about we americans from a song that created over 20k views on youtube and has alot of potential.
#
# musicians, marketers, representers of any kind from new york or online please help me  for branding and/or marketing cause of the potential of this song. a small fee is fine depending on the opportunity.thank you for your time. rg
#
# link: https://youtu.be/hwn0iq6bthc
#
# ---------------------------------------
#
# POST RANK:  18
# POST PROB:  0.385897435892
# URL:  https://houston.craigslist.org/muc/d/re-re-metal-singer-lookin-for/6342796407.html
# POST CONTENT:
#  Re: Re: METAL SINGER, lookin for cool metal band to playwhat's wrong with it?  he has a good metal voice.
#
# ---------------------------------------
#
# POST RANK:  19
# POST PROB:  0.379839240498
# URL:  https://newyork.craigslist.org/lgi/muc/d/mix-and-master-your-songs-for/6367463059.html
# POST CONTENT:
#  Mix and Master your songs for 20 a tracki am a recording engineer by the name of rich cash that specializes in hip hop r&b and alternative . i only mix vocals for this price . 1 verse freestylez i mix for 10 . price is firm . i mix in protools so prefer you send the session through wetransfer u can send your project and ill send back a snippet back for free so you can determine if u would like to work i accept pay pal. and western union but paypal is better . my expertise is hip hop and if you need autotune im the man . i also sell templates for 20 dollars with my preset settings .  the more tracks you send the more of a deal i can negotiate . please contact me at my email is in the contact with phone number
# thank you and lets work
#
# ---------------------------------------
#
# POST RANK:  20
# POST PROB:  0.379839240497
# URL:  https://hudsonvalley.craigslist.org/muc/d/mix-and-master-your-songs-for/6369899022.html
# POST CONTENT:
#  Mix and Master your songs for 20 a songi am a recording engineer by the name of rich cash that specializes in hip hop r&b and alternative . i only mix vocals for this price . 1 verse freestylez i mix for 10 . price is firm . i mix in protools so prefer you send the session through wetransfer u can send your project and ill send back a snippet back for free so you can determine if u would like to work i accept pay pal. and western union but paypal is better . my expertise is hip hop and if you need autotune im the man . i also sell templates for 20 dollars with my preset settings . the more tracks you send the more of a deal i can negotiate . please contact me at my email is in the contact with phone number
# thank you and lets work
#
# ---------------------------------------

# %%
import pickle 
pkg = [lda.components_, topics_matrix]
with open("./models/lda_12grams_30n-dedup.pkl", "wb") as f:
    pickle.dump(pkg, f)
